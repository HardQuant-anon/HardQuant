# %% [markdown]
# # Runing Falcon-180B on a single A100 80GB

# %% [markdown]
# This file including three section:
# - [(Optional) Train the quantization parameters of Falcon-180B by yourself.](#optional-train-the-quantization-parameters-of-falcon-180b-by-yourself)
# - [Download the pre-quantized models](#download-the-pre-quantized-models)
# - [Let's Infer!](#lets-infer)

# %% [markdown]
# ## (Optional) Train the quantization parameters of Mixtral-7bx8 by yourself.
#
# This section provids how to train the quantization parameters of Mixtral-7bx8 by yourself. You can skip this section because we have provided the pre-built quantized models in [Download the pre-quantized models](#download-the-pre-quantized-models).

# %%
# !pip install accelerate

# %%
# !CUDA_VISIBLE_DEVICES=0 python main.py \
  --model mistralai/Mixtral-8x7B-v0.1 \
  --epochs 10 --output_dir ./log/mixtral-8x7b_w4a16g128 \
  --wbits 4 --abits 16 --group_size 128 --lwc \
  --nsamples 128 --net mixtral-8x7b \
  --real_quant --eval_ppl \
  --save_dir ./checkpoint/mixtral-8x7b_w4a16g128
# Out:
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:418: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:461: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float16)
# CUDA extension not installed.
# CUDA extension not installed.
# ['main.py', '--model', 'mistralai/Mixtral-8x7B-v0.1', '--epochs', '10', '--output_dir', './log/mixtral-8x7b_w4a16g128', '--wbits', '4', '--abits', '16', '--group_size', '128', '--lwc', '--nsamples', '128', '--net', 'mixtral-8x7b', '--real_quant', '--eval_ppl', '--save_dir', './checkpoint/mixtral-8x7b_w4a16g128']
# [2025-12-31 14:23:23 root](main.py 258): INFO Namespace(model='mistralai/Mixtral-8x7B-v0.1', cache_dir='./cache', output_dir='./log/mixtral-8x7b_w4a16g128', save_dir='./checkpoint/mixtral-8x7b_w4a16g128', resume=None, real_quant=True, calib_dataset='wikitext2', nsamples=128, batch_size=1, seed=2, tasks='', eval_ppl=True, num_fewshot=0, wbits=4, abits=16, group_size=128, alpha=0.5, let_lr=0.005, lwc_lr=0.01, wd=0, epochs=10, let=False, lwc=True, aug_loss=False, symmetric=False, disable_zero_point=False, a_dynamic_method='per_token', w_dynamic_method='per_channel', limit=-1, multigpu=False, deactive_amp=False, attn_implementation='eager', net='mixtral-8x7b', act_scales=None, act_shifts=None)
# config.json: 100%|█████████████████████████████| 720/720 [00:00<00:00, 7.78MB/s]
# tokenizer_config.json: 100%|███████████████████| 967/967 [00:00<00:00, 12.7MB/s]
# tokenizer.model: 100%|███████████████████████| 493k/493k [00:00<00:00, 3.27MB/s]
# special_tokens_map.json: 100%|████████████████| 72.0/72.0 [00:00<00:00, 680kB/s]
# tokenizer.json: 1.80MB [00:00, 187MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 92.7kB [00:00, 302MB/s]
# Fetching 19 files:   0%|                                 | 0/19 [00:00<?, ?it/s]
# model-00002-of-00019.safetensors:   0%|             | 0.00/4.98G [00:00<?, ?B/s]
#
# model-00008-of-00019.safetensors:   0%|             | 0.00/4.98G [00:00<?, ?B/s]
#
#
# model-00005-of-00019.safetensors:   0%|             | 0.00/4.98G [00:00<?, ?B/s]
#
#
#
# model-00003-of-00019.safetensors:   0%|             | 0.00/4.98G [00:00<?, ?B/s]
#
#
#
#
# model-00004-of-00019.safetensors:   0%|             | 0.00/4.90G [00:00<?, ?B/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:   0%|             | 0.00/4.90G [00:00<?, ?B/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:   0%|             | 0.00/4.98G [00:00<?, ?B/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:   0%|             | 0.00/4.89G [00:00<?, ?B/s]
# model-00002-of-00019.safetensors:   0%|    | 827k/4.98G [00:01<1:45:18, 788kB/s]
#
#
#
# model-00003-of-00019.safetensors:   0%|    | 13.3M/4.98G [00:01<07:09, 11.6MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:   0%| | 10.3k/4.89G [00:01<152:02:56, 8.94kB/s
#
#
#
# model-00003-of-00019.safetensors:   3%|▏     | 160M/4.98G [00:01<00:29, 162MB/s]
#
#
# model-00005-of-00019.safetensors:   0%|    | 756k/4.98G [00:01<2:31:57, 546kB/s]
#
#
#
# model-00003-of-00019.safetensors:   6%|▍     | 319M/4.98G [00:01<00:13, 336MB/s]
#
#
#
# model-00003-of-00019.safetensors:  10%|▋     | 521M/4.98G [00:01<00:07, 577MB/s]
#
# model-00008-of-00019.safetensors:   1%|    | 67.1M/4.98G [00:01<01:53, 43.2MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:   1%|    | 67.0M/4.90G [00:01<01:51, 43.4MB/s]
# model-00002-of-00019.safetensors:   1%|    | 67.9M/4.98G [00:01<01:33, 52.4MB/s]
#
#
# model-00005-of-00019.safetensors:  13%|▊     | 671M/4.98G [00:01<00:07, 553MB/s]
#
#
#
# model-00003-of-00019.safetensors:  13%|▊     | 667M/4.98G [00:01<00:06, 683MB/s]
# model-00002-of-00019.safetensors:   5%|▎     | 269M/4.98G [00:01<00:19, 246MB/s]
#
#
# model-00005-of-00019.safetensors:  18%|█     | 873M/4.98G [00:01<00:06, 642MB/s]
#
# model-00008-of-00019.safetensors:   3%|▏    | 134M/4.98G [00:01<00:58, 82.2MB/s]
#
#
#
# model-00003-of-00019.safetensors:  17%|█     | 849M/4.98G [00:01<00:05, 720MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:   1%|    | 67.1M/4.98G [00:02<02:29, 33.0MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:   1%|    | 61.0M/4.89G [00:02<02:16, 35.5MB/s]
#
#
#
# model-00003-of-00019.safetensors:  19%|█▏    | 955M/4.98G [00:02<00:06, 586MB/s]
# model-00002-of-00019.safetensors:   8%|▍     | 403M/4.98G [00:02<00:17, 255MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:   1%|    | 67.0M/4.90G [00:02<02:39, 30.3MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:   3%|▏    | 134M/4.98G [00:02<01:07, 71.7MB/s]
#
#
# model-00005-of-00019.safetensors:  22%|█    | 1.07G/4.98G [00:02<00:06, 591MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:   2%|     | 113M/4.89G [00:02<01:07, 71.0MB/s]
#
# model-00008-of-00019.safetensors:   4%|▏     | 202M/4.98G [00:02<00:44, 108MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:   3%|▏    | 134M/4.90G [00:02<01:15, 63.5MB/s]
# model-00002-of-00019.safetensors:   9%|▌     | 470M/4.98G [00:02<00:15, 292MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:   5%|▎     | 268M/4.98G [00:02<00:26, 175MB/s]
#
# model-00008-of-00019.safetensors:   7%|▍     | 336M/4.98G [00:02<00:20, 221MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:   4%|▏     | 201M/4.90G [00:02<00:43, 108MB/s]
#
#
#
# model-00003-of-00019.safetensors:  21%|█    | 1.06G/4.98G [00:02<00:06, 582MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:   4%|▏     | 181M/4.89G [00:02<00:39, 120MB/s]
#
#
# model-00005-of-00019.safetensors:  24%|█▏   | 1.21G/4.98G [00:02<00:06, 591MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:   8%|▍     | 402M/4.90G [00:02<00:16, 278MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:   3%|▏    | 135M/4.90G [00:02<01:18, 60.7MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:   5%|▎     | 248M/4.89G [00:02<00:28, 161MB/s]
#
#
#
# model-00003-of-00019.safetensors:  25%|█▎   | 1.26G/4.98G [00:02<00:06, 593MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:   5%|▎     | 269M/4.90G [00:02<00:32, 144MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:   9%|▌     | 449M/4.89G [00:02<00:11, 380MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:   8%|▍     | 403M/4.98G [00:02<00:20, 223MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  11%|▋     | 530M/4.89G [00:02<00:10, 423MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:   9%|▌     | 470M/4.98G [00:02<00:17, 257MB/s]
#
# model-00008-of-00019.safetensors:   9%|▌     | 470M/4.98G [00:02<00:19, 229MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  11%|▋     | 537M/4.90G [00:02<00:14, 296MB/s]
#
#
# model-00005-of-00019.safetensors:  27%|█▎   | 1.34G/4.98G [00:02<00:08, 454MB/s]
# model-00002-of-00019.safetensors:  13%|▊     | 671M/4.98G [00:03<00:14, 294MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  12%|▋     | 604M/4.90G [00:03<00:13, 309MB/s]
#
#
#
# model-00003-of-00019.safetensors:  28%|█▍   | 1.37G/4.98G [00:03<00:08, 439MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:   7%|▍     | 336M/4.90G [00:03<00:31, 145MB/s]
#
#
# model-00005-of-00019.safetensors:  30%|█▍   | 1.48G/4.98G [00:03<00:07, 481MB/s]
# model-00002-of-00019.safetensors:  20%|█    | 1.01G/4.98G [00:03<00:07, 535MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  11%|▋     | 537M/4.98G [00:03<00:19, 227MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  14%|▊     | 664M/4.89G [00:03<00:11, 379MB/s]
#
#
#
# model-00003-of-00019.safetensors:  29%|█▍   | 1.46G/4.98G [00:03<00:07, 472MB/s]
#
#
# model-00005-of-00019.safetensors:  32%|█▌   | 1.61G/4.98G [00:03<00:05, 573MB/s]
#
#
#
# model-00003-of-00019.safetensors:  31%|█▌   | 1.55G/4.98G [00:03<00:07, 464MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  12%|▋     | 604M/4.90G [00:03<00:16, 254MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  14%|▊     | 671M/4.90G [00:03<00:20, 203MB/s]
#
#
#
# model-00003-of-00019.safetensors:  32%|█▌   | 1.61G/4.98G [00:03<00:08, 376MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  15%|▉     | 731M/4.89G [00:03<00:16, 255MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  12%|▋     | 604M/4.98G [00:03<00:25, 171MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  15%|▉     | 738M/4.90G [00:03<00:12, 329MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  19%|█▏    | 940M/4.90G [00:03<00:09, 398MB/s]
# model-00002-of-00019.safetensors:  23%|█▏   | 1.14G/4.98G [00:04<00:10, 351MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  18%|█     | 873M/4.89G [00:03<00:11, 359MB/s]
#
# model-00008-of-00019.safetensors:  12%|▋     | 604M/4.98G [00:04<00:25, 170MB/s]
#
#
# model-00005-of-00019.safetensors:  35%|█▊   | 1.75G/4.98G [00:04<00:08, 365MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  19%|█▏    | 940M/4.98G [00:04<00:09, 449MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  21%|█    | 1.01G/4.90G [00:04<00:07, 529MB/s]
#
#
# model-00005-of-00019.safetensors:  40%|██   | 2.01G/4.98G [00:04<00:05, 572MB/s]
# model-00002-of-00019.safetensors:  26%|█▎   | 1.28G/4.98G [00:04<00:09, 410MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  22%|█    | 1.07G/4.90G [00:04<00:10, 367MB/s]
# model-00002-of-00019.safetensors:  30%|█▍   | 1.48G/4.98G [00:04<00:07, 465MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  22%|█    | 1.08G/4.89G [00:04<00:10, 378MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  22%|█    | 1.07G/4.98G [00:04<00:10, 370MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  23%|█▏   | 1.14G/4.90G [00:04<00:09, 404MB/s]
# model-00002-of-00019.safetensors:  35%|█▊   | 1.75G/4.98G [00:04<00:05, 641MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  23%|█▏   | 1.15G/4.89G [00:04<00:09, 384MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  23%|█▏   | 1.14G/4.90G [00:04<00:11, 316MB/s]
# model-00002-of-00019.safetensors:  38%|█▉   | 1.88G/4.98G [00:04<00:04, 713MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  25%|█▏   | 1.22G/4.89G [00:04<00:09, 386MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  29%|█▍   | 1.41G/4.90G [00:04<00:06, 518MB/s]
# model-00002-of-00019.safetensors:  40%|██   | 2.02G/4.98G [00:04<00:04, 724MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  26%|█▎   | 1.27G/4.90G [00:04<00:08, 409MB/s]
#
# model-00008-of-00019.safetensors:  23%|█▏   | 1.14G/4.98G [00:05<00:12, 318MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  27%|█▎   | 1.34G/4.90G [00:05<00:08, 434MB/s]
# model-00002-of-00019.safetensors:  43%|██▏  | 2.15G/4.98G [00:05<00:03, 815MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  26%|█▎   | 1.28G/4.89G [00:05<00:09, 366MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  24%|█▏   | 1.21G/4.98G [00:05<00:11, 336MB/s]
#
#
#
# model-00003-of-00019.safetensors:  34%|█▋   | 1.68G/4.98G [00:05<00:21, 157MB/s]
#
#
# model-00005-of-00019.safetensors:  44%|██▏  | 2.21G/4.98G [00:05<00:07, 369MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  32%|█▌   | 1.54G/4.90G [00:05<00:06, 532MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  29%|█▍   | 1.41G/4.90G [00:05<00:07, 442MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  28%|█▍   | 1.35G/4.89G [00:05<00:09, 381MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  28%|█▍   | 1.41G/4.98G [00:05<00:08, 446MB/s]
# model-00002-of-00019.safetensors:  46%|██▎  | 2.28G/4.98G [00:05<00:03, 740MB/s]
#
# model-00008-of-00019.safetensors:  27%|█▎   | 1.34G/4.98G [00:05<00:10, 364MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  34%|█▋   | 1.68G/4.90G [00:05<00:04, 663MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  29%|█▍   | 1.42G/4.89G [00:05<00:09, 360MB/s]
#
#
# model-00005-of-00019.safetensors:  47%|██▎  | 2.35G/4.98G [00:05<00:07, 362MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  30%|█▌   | 1.48G/4.89G [00:05<00:08, 393MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  31%|█▌   | 1.54G/4.98G [00:05<00:07, 448MB/s]
#
#
# model-00005-of-00019.safetensors:  48%|██▍  | 2.42G/4.98G [00:05<00:06, 367MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  34%|█▋   | 1.68G/4.90G [00:05<00:07, 422MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  37%|█▊   | 1.81G/4.90G [00:05<00:05, 604MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  32%|█▌   | 1.57G/4.89G [00:05<00:10, 315MB/s]
#
#
#
# model-00003-of-00019.safetensors:  43%|██▏  | 2.17G/4.98G [00:05<00:08, 317MB/s]
#
#
# model-00005-of-00019.safetensors:  50%|██▍  | 2.48G/4.98G [00:05<00:07, 330MB/s]
#
# model-00008-of-00019.safetensors:  28%|█▍   | 1.41G/4.98G [00:05<00:12, 289MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  36%|█▊   | 1.75G/4.90G [00:06<00:09, 345MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  40%|█▉   | 1.94G/4.90G [00:06<00:05, 514MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  34%|█▋   | 1.68G/4.98G [00:06<00:08, 377MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  38%|█▉   | 1.84G/4.89G [00:06<00:05, 588MB/s]
#
#
# model-00005-of-00019.safetensors:  54%|██▋  | 2.68G/4.98G [00:06<00:04, 468MB/s]
#
# model-00008-of-00019.safetensors:  31%|█▌   | 1.54G/4.98G [00:06<00:10, 343MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  41%|██   | 2.01G/4.90G [00:06<00:05, 527MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  35%|█▋   | 1.74G/4.98G [00:06<00:08, 405MB/s]
# model-00002-of-00019.safetensors:  49%|██▍  | 2.42G/4.98G [00:06<00:07, 345MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  42%|██   | 2.08G/4.90G [00:06<00:05, 546MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  39%|█▉   | 1.94G/4.98G [00:06<00:05, 603MB/s]
#
#
#
# model-00003-of-00019.safetensors:  45%|██▏  | 2.23G/4.98G [00:06<00:09, 291MB/s]
#
#
# model-00005-of-00019.safetensors:  55%|██▊  | 2.75G/4.98G [00:06<00:04, 456MB/s]
#
# model-00008-of-00019.safetensors:  34%|█▋   | 1.68G/4.98G [00:06<00:08, 398MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  38%|█▉   | 1.88G/4.90G [00:06<00:08, 372MB/s]
#
# model-00008-of-00019.safetensors:  35%|█▋   | 1.74G/4.98G [00:06<00:07, 421MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  45%|██▎  | 2.21G/4.90G [00:06<00:04, 608MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  40%|██   | 1.97G/4.89G [00:06<00:06, 479MB/s]
#
#
# model-00005-of-00019.safetensors:  58%|██▉  | 2.89G/4.98G [00:06<00:04, 489MB/s]
# model-00002-of-00019.safetensors:  57%|██▊  | 2.82G/4.98G [00:06<00:03, 553MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  42%|██   | 2.08G/4.98G [00:06<00:05, 515MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  47%|██▎  | 2.28G/4.90G [00:06<00:05, 453MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  41%|██   | 2.03G/4.89G [00:06<00:07, 398MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  42%|██   | 2.08G/4.90G [00:06<00:07, 376MB/s]
#
# model-00008-of-00019.safetensors:  38%|█▉   | 1.88G/4.98G [00:06<00:08, 369MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  48%|██▍  | 2.35G/4.90G [00:06<00:05, 445MB/s]
#
#
#
# model-00003-of-00019.safetensors:  48%|██▍  | 2.37G/4.98G [00:06<00:09, 268MB/s]
#
#
# model-00005-of-00019.safetensors:  61%|███  | 3.02G/4.98G [00:07<00:04, 408MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  44%|██▏  | 2.21G/4.98G [00:07<00:06, 459MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  44%|██▏  | 2.15G/4.90G [00:07<00:07, 390MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  46%|██▎  | 2.23G/4.89G [00:07<00:05, 516MB/s]
#
# model-00008-of-00019.safetensors:  40%|██   | 2.01G/4.98G [00:07<00:07, 415MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  47%|██▎  | 2.30G/4.89G [00:07<00:04, 537MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  47%|██▎  | 2.35G/4.98G [00:07<00:05, 523MB/s]
#
#
#
# model-00003-of-00019.safetensors:  50%|██▌  | 2.49G/4.98G [00:07<00:08, 297MB/s]
#
#
# model-00005-of-00019.safetensors:  65%|███▏ | 3.22G/4.98G [00:07<00:03, 506MB/s]
#
# model-00008-of-00019.safetensors:  44%|██▏  | 2.21G/4.98G [00:07<00:04, 575MB/s]
#
#
#
# model-00003-of-00019.safetensors:  51%|██▌  | 2.53G/4.98G [00:07<00:08, 290MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  49%|██▍  | 2.42G/4.90G [00:07<00:08, 298MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  50%|██▍  | 2.43G/4.89G [00:07<00:04, 564MB/s]
# model-00002-of-00019.safetensors:  59%|██▉  | 2.95G/4.98G [00:07<00:05, 360MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  49%|██▍  | 2.42G/4.90G [00:07<00:05, 449MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  51%|██▌  | 2.48G/4.90G [00:07<00:08, 294MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  51%|██▌  | 2.50G/4.89G [00:07<00:05, 472MB/s]
#
#
#
# model-00003-of-00019.safetensors:  54%|██▋  | 2.70G/4.98G [00:07<00:06, 360MB/s]
# model-00002-of-00019.safetensors:  61%|███  | 3.02G/4.98G [00:07<00:05, 355MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  52%|██▌  | 2.55G/4.90G [00:07<00:04, 497MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  53%|██▋  | 2.62G/4.90G [00:07<00:05, 432MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  50%|██▍  | 2.48G/4.98G [00:07<00:06, 394MB/s]
#
#
# model-00005-of-00019.safetensors:  69%|███▍ | 3.42G/4.98G [00:07<00:03, 467MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  55%|██▋  | 2.68G/4.90G [00:07<00:04, 470MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  51%|██▌  | 2.55G/4.98G [00:07<00:05, 408MB/s]
#
#
# model-00005-of-00019.safetensors:  70%|███▌ | 3.49G/4.98G [00:07<00:03, 468MB/s]
# model-00002-of-00019.safetensors:  62%|███  | 3.09G/4.98G [00:07<00:05, 347MB/s]
#
#
#
# model-00003-of-00019.safetensors:  57%|██▊  | 2.83G/4.98G [00:07<00:05, 396MB/s]
#
#
# model-00005-of-00019.safetensors:  73%|███▋ | 3.62G/4.98G [00:07<00:02, 577MB/s]
# model-00002-of-00019.safetensors:  63%|███▏ | 3.15G/4.98G [00:08<00:04, 378MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  53%|██▋  | 2.62G/4.90G [00:08<00:05, 419MB/s]
#
#
# model-00005-of-00019.safetensors:  75%|███▊ | 3.76G/4.98G [00:08<00:01, 681MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  56%|██▊  | 2.75G/4.90G [00:08<00:05, 381MB/s]
#
# model-00008-of-00019.safetensors:  47%|██▎  | 2.35G/4.98G [00:08<00:07, 340MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  55%|██▋  | 2.68G/4.90G [00:08<00:04, 448MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  52%|██▌  | 2.57G/4.89G [00:08<00:07, 305MB/s]
#
#
#
# model-00003-of-00019.safetensors:  59%|██▉  | 2.95G/4.98G [00:08<00:04, 425MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  55%|██▊  | 2.75G/4.98G [00:08<00:04, 480MB/s]
# model-00002-of-00019.safetensors:  67%|███▎ | 3.36G/4.98G [00:08<00:03, 515MB/s]
#
# model-00008-of-00019.safetensors:  53%|██▋  | 2.62G/4.98G [00:08<00:04, 550MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  53%|██▋  | 2.62G/4.89G [00:08<00:07, 314MB/s]
#
#
# model-00005-of-00019.safetensors:  78%|███▉ | 3.89G/4.98G [00:08<00:01, 695MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  58%|██▉  | 2.82G/4.90G [00:08<00:04, 486MB/s]
#
#
#
# model-00003-of-00019.safetensors:  60%|███  | 3.00G/4.98G [00:08<00:05, 394MB/s]
#
# model-00008-of-00019.safetensors:  55%|██▊  | 2.75G/4.98G [00:08<00:04, 528MB/s]
#
#
#
# model-00003-of-00019.safetensors:  61%|███  | 3.05G/4.98G [00:08<00:05, 373MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  59%|██▉  | 2.89G/4.90G [00:08<00:04, 474MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  58%|██▉  | 2.82G/4.89G [00:08<00:04, 459MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  58%|██▉  | 2.82G/4.90G [00:08<00:07, 267MB/s]
# model-00002-of-00019.safetensors:  70%|███▌ | 3.49G/4.98G [00:08<00:03, 452MB/s]
#
#
# model-00005-of-00019.safetensors:  81%|████ | 4.03G/4.98G [00:08<00:01, 485MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  59%|██▉  | 2.89G/4.90G [00:08<00:07, 271MB/s]
# model-00002-of-00019.safetensors:  74%|███▋ | 3.69G/4.98G [00:08<00:02, 549MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  60%|███  | 2.95G/4.90G [00:08<00:05, 360MB/s]
#
#
#
# model-00003-of-00019.safetensors:  63%|███▏ | 3.14G/4.98G [00:08<00:05, 326MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  57%|██▊  | 2.83G/4.98G [00:08<00:07, 288MB/s]
# model-00002-of-00019.safetensors:  78%|███▉ | 3.89G/4.98G [00:08<00:01, 738MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  64%|███▏ | 3.15G/4.90G [00:08<00:03, 565MB/s]
#
#
# model-00005-of-00019.safetensors:  84%|████▏| 4.17G/4.98G [00:09<00:01, 447MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  60%|███  | 2.96G/4.89G [00:09<00:05, 336MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  62%|███  | 3.02G/4.90G [00:09<00:05, 314MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  58%|██▉  | 2.90G/4.98G [00:09<00:07, 288MB/s]
# model-00002-of-00019.safetensors:  81%|████ | 4.02G/4.98G [00:09<00:01, 636MB/s]
#
# model-00008-of-00019.safetensors:  58%|██▉  | 2.89G/4.98G [00:09<00:05, 354MB/s]
#
#
#
# model-00003-of-00019.safetensors:  65%|███▏ | 3.21G/4.98G [00:09<00:06, 276MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  67%|███▎ | 3.29G/4.90G [00:09<00:02, 542MB/s]
#
#
# model-00005-of-00019.safetensors:  88%|████▍| 4.37G/4.98G [00:09<00:01, 596MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  63%|███▏ | 3.08G/4.89G [00:09<00:04, 407MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  61%|███  | 3.03G/4.98G [00:09<00:05, 361MB/s]
#
#
#
# model-00003-of-00019.safetensors:  66%|███▎ | 3.27G/4.98G [00:09<00:05, 292MB/s]
# model-00002-of-00019.safetensors:  83%|████▏| 4.16G/4.98G [00:09<00:01, 624MB/s]
#
# model-00008-of-00019.safetensors:  61%|███  | 3.02G/4.98G [00:09<00:04, 394MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  66%|███▎ | 3.22G/4.90G [00:09<00:04, 408MB/s]
#
#
#
# model-00003-of-00019.safetensors:  69%|███▍ | 3.42G/4.98G [00:09<00:03, 460MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  68%|███▍ | 3.36G/4.90G [00:09<00:03, 443MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  64%|███▏ | 3.15G/4.89G [00:09<00:04, 372MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  62%|███  | 3.10G/4.98G [00:09<00:05, 338MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  70%|███▍ | 3.43G/4.90G [00:09<00:03, 472MB/s]
#
#
# model-00005-of-00019.safetensors:  90%|████▌| 4.50G/4.98G [00:09<00:00, 502MB/s]
#
#
#
# model-00003-of-00019.safetensors:  70%|███▍ | 3.48G/4.98G [00:09<00:04, 354MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  71%|███▌ | 3.49G/4.90G [00:09<00:03, 435MB/s]
#
#
# model-00005-of-00019.safetensors:  92%|████▌| 4.58G/4.98G [00:09<00:00, 492MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  66%|███▎ | 3.22G/4.89G [00:09<00:05, 328MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  66%|███▎ | 3.31G/4.98G [00:09<00:03, 441MB/s]
# model-00002-of-00019.safetensors:  85%|████▎| 4.25G/4.98G [00:09<00:01, 425MB/s]
#
#
#
# model-00003-of-00019.safetensors:  71%|███▌ | 3.54G/4.98G [00:09<00:03, 386MB/s]
#
# model-00008-of-00019.safetensors:  63%|███▏ | 3.15G/4.98G [00:09<00:05, 357MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  74%|███▋ | 3.63G/4.90G [00:10<00:02, 517MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  68%|███▍ | 3.37G/4.98G [00:10<00:03, 443MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  68%|███▍ | 3.35G/4.89G [00:10<00:03, 396MB/s]
# model-00002-of-00019.safetensors:  87%|████▎| 4.31G/4.98G [00:10<00:01, 425MB/s]
#
#
# model-00005-of-00019.safetensors:  93%|████▋| 4.65G/4.98G [00:10<00:00, 424MB/s]
#
# model-00008-of-00019.safetensors:  65%|███▏ | 3.22G/4.98G [00:10<00:05, 339MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  71%|███▌ | 3.49G/4.90G [00:10<00:03, 388MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  70%|███▍ | 3.42G/4.89G [00:10<00:03, 386MB/s]
#
#
#
# model-00003-of-00019.safetensors:  73%|███▋ | 3.64G/4.98G [00:10<00:03, 342MB/s]
# model-00002-of-00019.safetensors:  88%|████▍| 4.38G/4.98G [00:10<00:01, 399MB/s]
#
# model-00008-of-00019.safetensors:  66%|███▎ | 3.29G/4.98G [00:10<00:04, 366MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  75%|███▊ | 3.69G/4.90G [00:10<00:03, 370MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  71%|███▌ | 3.48G/4.89G [00:10<00:03, 391MB/s]
#
#
# model-00005-of-00019.safetensors:  96%|████▊| 4.78G/4.98G [00:10<00:00, 404MB/s]
#
# model-00008-of-00019.safetensors:  67%|███▎ | 3.36G/4.98G [00:10<00:04, 383MB/s]
#
#
#
# model-00003-of-00019.safetensors:  74%|███▋ | 3.71G/4.98G [00:10<00:03, 344MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  69%|███▍ | 3.44G/4.98G [00:10<00:04, 326MB/s]
# model-00002-of-00019.safetensors:  89%|████▍| 4.45G/4.98G [00:10<00:01, 373MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  78%|███▉ | 3.83G/4.90G [00:10<00:02, 494MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  75%|███▊ | 3.69G/4.90G [00:10<00:02, 454MB/s]
# model-00002-of-00019.safetensors:  92%|████▌| 4.58G/4.98G [00:10<00:00, 508MB/s]
#
# model-00008-of-00019.safetensors:  69%|███▍ | 3.42G/4.98G [00:10<00:04, 390MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  72%|███▌ | 3.57G/4.98G [00:10<00:03, 418MB/s]
#
#
#
# model-00003-of-00019.safetensors:  77%|███▊ | 3.83G/4.98G [00:10<00:02, 411MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  73%|███▋ | 3.64G/4.98G [00:10<00:02, 449MB/s]
#
#
# model-00005-of-00019.safetensors:  99%|████▉| 4.92G/4.98G [00:10<00:00, 422MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  74%|███▋ | 3.62G/4.89G [00:10<00:03, 397MB/s]
# model-00002-of-00019.safetensors:  95%|████▋| 4.71G/4.98G [00:10<00:00, 608MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  78%|███▉ | 3.83G/4.90G [00:10<00:02, 458MB/s]
#
# model-00008-of-00019.safetensors:  71%|███▌ | 3.56G/4.98G [00:10<00:02, 481MB/s]
#
#
# model-00005-of-00019.safetensors: 100%|█████| 4.98G/4.98G [00:10<00:00, 426MB/s]
#
#
#
#
# model-00005-of-00019.safetensors: 100%|█████| 4.98G/4.98G [00:10<00:00, 457MB/s]
#
#
# model-00008-of-00019.safetensors:  73%|███▋ | 3.62G/4.98G [00:10<00:02, 484MB/s]
#
#
# model-00009-of-00019.safetensors:   0%|             | 0.00/4.98G [00:00<?, ?B/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  74%|███▋ | 3.71G/4.98G [00:10<00:03, 382MB/s]
#
#
#
# model-00003-of-00019.safetensors:  78%|███▉ | 3.88G/4.98G [00:11<00:03, 298MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  82%|████ | 4.03G/4.90G [00:11<00:02, 426MB/s]
#
# model-00008-of-00019.safetensors:  74%|███▋ | 3.71G/4.98G [00:11<00:02, 475MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  76%|███▊ | 3.78G/4.98G [00:11<00:03, 401MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  78%|███▉ | 3.82G/4.89G [00:11<00:02, 436MB/s]
#
#
#
# model-00003-of-00019.safetensors:  79%|███▉ | 3.93G/4.98G [00:11<00:03, 309MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  82%|████ | 4.03G/4.90G [00:11<00:01, 459MB/s]
#
# model-00008-of-00019.safetensors:  76%|███▊ | 3.78G/4.98G [00:11<00:02, 509MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  79%|███▉ | 3.89G/4.89G [00:11<00:02, 427MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  85%|████▏| 4.16G/4.90G [00:11<00:01, 539MB/s]
#
# model-00008-of-00019.safetensors:  79%|███▉ | 3.91G/4.98G [00:11<00:01, 624MB/s]
#
#
#
# model-00003-of-00019.safetensors:  80%|███▉ | 3.98G/4.98G [00:11<00:03, 289MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  84%|████▏| 4.09G/4.90G [00:11<00:02, 349MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  77%|███▊ | 3.84G/4.98G [00:11<00:03, 317MB/s]
# model-00002-of-00019.safetensors:  97%|████▊| 4.85G/4.98G [00:11<00:00, 339MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  84%|████▏| 4.09G/4.89G [00:11<00:01, 589MB/s]
#
#
#
# model-00003-of-00019.safetensors:  83%|████▏| 4.11G/4.98G [00:11<00:01, 451MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  85%|████▏| 4.16G/4.90G [00:11<00:01, 375MB/s]
#
# model-00008-of-00019.safetensors:  81%|████ | 4.05G/4.98G [00:11<00:01, 613MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  80%|███▉ | 3.98G/4.98G [00:11<00:02, 446MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  86%|████▎| 4.23G/4.90G [00:11<00:01, 442MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  89%|████▍| 4.36G/4.90G [00:11<00:00, 595MB/s]
# model-00002-of-00019.safetensors:  99%|████▉| 4.92G/4.98G [00:11<00:00, 349MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  85%|████▏| 4.16G/4.89G [00:11<00:01, 506MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  90%|████▌| 4.43G/4.90G [00:11<00:00, 633MB/s]
# model-00002-of-00019.safetensors: 100%|█████| 4.98G/4.98G [00:11<00:00, 420MB/s]
#
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  83%|████▏| 4.11G/4.98G [00:11<00:01, 483MB/s]
#
#
#
# model-00003-of-00019.safetensors:  84%|████▏| 4.20G/4.98G [00:11<00:02, 345MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  93%|████▋| 4.56G/4.90G [00:11<00:00, 736MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  92%|████▌| 4.50G/4.90G [00:11<00:00, 573MB/s]
# model-00010-of-00019.safetensors:   0%|             | 0.00/4.90G [00:00<?, ?B/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  84%|████▏| 4.18G/4.98G [00:11<00:01, 496MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  95%|████▋| 4.63G/4.90G [00:12<00:00, 663MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  88%|████▍| 4.29G/4.89G [00:12<00:01, 454MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  85%|████▎| 4.25G/4.98G [00:12<00:01, 523MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  96%|████▊| 4.70G/4.90G [00:12<00:00, 635MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  89%|████▍| 4.36G/4.89G [00:12<00:01, 477MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  88%|████▍| 4.38G/4.98G [00:12<00:00, 662MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors:  97%|████▊| 4.76G/4.90G [00:12<00:00, 665MB/s]
#
#
#
# model-00003-of-00019.safetensors:  86%|████▎| 4.26G/4.98G [00:12<00:02, 287MB/s]
#
# model-00008-of-00019.safetensors:  84%|████▏| 4.18G/4.98G [00:12<00:02, 363MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  90%|████▌| 4.42G/4.89G [00:12<00:00, 484MB/s]
#
#
#
# model-00003-of-00019.safetensors:  87%|████▎| 4.35G/4.98G [00:12<00:01, 351MB/s]
#
# model-00008-of-00019.safetensors:  88%|████▍| 4.38G/4.98G [00:12<00:01, 531MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  91%|████▌| 4.51G/4.98G [00:12<00:00, 633MB/s]
#
#
# model-00009-of-00019.safetensors:   0%|    | 594k/4.98G [00:01<3:25:53, 403kB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  95%|████▋| 4.62G/4.89G [00:12<00:00, 683MB/s]
#
#
#
#
# model-00004-of-00019.safetensors:  99%|████▉| 4.83G/4.90G [00:12<00:00, 539MB/s]
#
# model-00008-of-00019.safetensors:  91%|████▌| 4.51G/4.98G [00:12<00:00, 628MB/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  95%|████▋| 4.71G/4.98G [00:12<00:00, 903MB/s]
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors:  97%|████▊| 4.76G/4.89G [00:12<00:00, 794MB/s]
#
#
#
# model-00003-of-00019.safetensors:  88%|████▍| 4.40G/4.98G [00:12<00:01, 295MB/s]
#
#
#
#
#
# model-00007-of-00019.safetensors: 100%|█████| 4.90G/4.90G [00:12<00:00, 387MB/s]
#
#
# model-00008-of-00019.safetensors:  93%|████▋| 4.65G/4.98G [00:12<00:00, 666MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:   0%|             | 0.00/4.98G [00:00<?, ?B/s]
#
#
#
#
#
#
# model-00006-of-00019.safetensors:  99%|████▉| 4.92G/4.98G [00:12<00:00, 954MB/s]
#
#
#
# model-00006-of-00019.safetensors: 100%|█████| 4.98G/4.98G [00:12<00:00, 391MB/s]
#
#
#
#
#
#
#
#
# model-00001-of-00019.safetensors: 100%|█████| 4.89G/4.89G [00:12<00:00, 384MB/s]
# model-00004-of-00019.safetensors: 100%|█████| 4.90G/4.90G [00:12<00:00, 383MB/s]
#
#
# model-00008-of-00019.safetensors:  96%|████▊| 4.78G/4.98G [00:12<00:00, 726MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:   0%|             | 0.00/4.98G [00:00<?, ?B/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:   0%|             | 0.00/4.90G [00:00<?, ?B/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:   0%|             | 0.00/4.98G [00:00<?, ?B/s]
#
#
#
# model-00003-of-00019.safetensors:  92%|████▌| 4.57G/4.98G [00:12<00:00, 425MB/s]
#
#
#
# model-00003-of-00019.safetensors:  95%|████▊| 4.74G/4.98G [00:13<00:00, 592MB/s]
#
# model-00008-of-00019.safetensors:  99%|████▉| 4.92G/4.98G [00:13<00:00, 617MB/s]
#
#
# model-00008-of-00019.safetensors: 100%|█████| 4.98G/4.98G [00:13<00:00, 377MB/s]
#
#
#
#
# model-00003-of-00019.safetensors:  97%|████▊| 4.85G/4.98G [00:13<00:00, 602MB/s]
#
# model-00015-of-00019.safetensors:   0%|             | 0.00/4.98G [00:00<?, ?B/s]
# model-00010-of-00019.safetensors:   0%|    | 647k/4.90G [00:01<2:59:40, 454kB/s]
#
#
#
# model-00003-of-00019.safetensors: 100%|█████| 4.98G/4.98G [00:13<00:00, 371MB/s]
# Fetching 19 files:  16%|███▉                     | 3/19 [00:13<00:58,  3.66s/it]
# model-00010-of-00019.safetensors:   4%|▏     | 202M/4.90G [00:01<00:25, 182MB/s]
#
#
#
# model-00016-of-00019.safetensors:   0%|             | 0.00/4.98G [00:00<?, ?B/s]
#
#
# model-00009-of-00019.safetensors:  13%|▊     | 671M/4.98G [00:02<00:13, 331MB/s]
# model-00010-of-00019.safetensors:  10%|▌     | 470M/4.90G [00:02<00:14, 301MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:   1%|    | 67.1M/4.90G [00:01<01:28, 54.8MB/s]
#
#
# model-00009-of-00019.safetensors:  38%|█▌  | 1.88G/4.98G [00:03<00:02, 1.05GB/s]
# model-00010-of-00019.safetensors:  23%|█▏   | 1.14G/4.90G [00:02<00:04, 891MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:   0%|    | 662k/4.98G [00:01<3:06:04, 446kB/s]
#
#
# model-00009-of-00019.safetensors:  43%|█▋  | 2.15G/4.98G [00:03<00:02, 1.16GB/s]
# model-00010-of-00019.safetensors:  29%|█▏  | 1.41G/4.90G [00:02<00:03, 1.00GB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:   1%|    | 67.8M/4.98G [00:01<01:26, 57.0MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:   3%|▏    | 134M/4.90G [00:01<00:51, 92.7MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:   1%|    | 67.0M/4.98G [00:01<01:58, 41.5MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:   1%|    | 67.1M/4.98G [00:01<02:04, 39.5MB/s]
# model-00010-of-00019.safetensors:  41%|█▋  | 2.01G/4.90G [00:02<00:01, 1.48GB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:   7%|▍     | 335M/4.90G [00:01<00:15, 287MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:   4%|▏     | 201M/4.98G [00:01<00:33, 143MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:   3%|▏     | 135M/4.98G [00:01<00:45, 106MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:   4%|▏     | 201M/4.98G [00:01<00:36, 129MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:   5%|▎     | 268M/4.98G [00:02<00:28, 168MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:   4%|▏     | 202M/4.98G [00:02<00:33, 143MB/s]
#
#
#
# model-00016-of-00019.safetensors:   1%|    | 67.0M/4.98G [00:01<01:50, 44.4MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  10%|▌     | 469M/4.90G [00:02<00:15, 294MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:   8%|▍     | 402M/4.98G [00:02<00:17, 268MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:   7%|▍     | 336M/4.98G [00:02<00:17, 262MB/s]
#
# model-00015-of-00019.safetensors:   1%|    | 67.1M/4.98G [00:01<02:14, 36.6MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:   5%|▎     | 269M/4.98G [00:02<00:32, 146MB/s]
# model-00010-of-00019.safetensors:  47%|██▎  | 2.28G/4.90G [00:03<00:02, 992MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  11%|▋     | 537M/4.90G [00:02<00:13, 328MB/s]
#
# model-00015-of-00019.safetensors:   3%|▏    | 134M/4.98G [00:01<00:58, 82.3MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:   7%|▍     | 336M/4.98G [00:02<00:24, 193MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  12%|▋     | 604M/4.90G [00:02<00:11, 366MB/s]
#
#
# model-00009-of-00019.safetensors:  48%|██▍  | 2.42G/4.98G [00:04<00:03, 680MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  12%|▋     | 604M/4.98G [00:02<00:10, 432MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:   9%|▌     | 470M/4.98G [00:02<00:14, 318MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:   8%|▍     | 403M/4.98G [00:02<00:18, 253MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  15%|▉     | 739M/4.98G [00:02<00:08, 516MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  12%|▋     | 604M/4.98G [00:02<00:09, 473MB/s]
#
#
#
# model-00016-of-00019.safetensors:   4%|▏     | 201M/4.98G [00:02<00:42, 114MB/s]
#
# model-00015-of-00019.safetensors:   7%|▍     | 335M/4.98G [00:02<00:24, 192MB/s]
# model-00010-of-00019.safetensors:  51%|██▌  | 2.48G/4.90G [00:03<00:03, 723MB/s]
#
#
# model-00009-of-00019.safetensors:  53%|██▋  | 2.62G/4.98G [00:04<00:03, 603MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  11%|▋     | 537M/4.98G [00:02<00:17, 254MB/s]
#
#
#
# model-00016-of-00019.safetensors:   8%|▍     | 402M/4.98G [00:02<00:19, 229MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  15%|▉     | 738M/4.98G [00:03<00:10, 390MB/s]
#
#
# model-00009-of-00019.safetensors:  55%|██▊  | 2.75G/4.98G [00:05<00:03, 592MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  18%|█     | 873M/4.98G [00:03<00:11, 369MB/s]
#
# model-00015-of-00019.safetensors:   8%|▍     | 402M/4.98G [00:02<00:23, 199MB/s]
#
# model-00015-of-00019.safetensors:   9%|▌     | 469M/4.98G [00:02<00:18, 244MB/s]
#
#
#
# model-00016-of-00019.safetensors:  11%|▋     | 536M/4.98G [00:02<00:15, 285MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  15%|▉     | 738M/4.90G [00:03<00:18, 229MB/s]
#
#
# model-00009-of-00019.safetensors:  58%|██▉  | 2.89G/4.98G [00:05<00:03, 613MB/s]
#
#
#
# model-00016-of-00019.safetensors:  12%|▋     | 604M/4.98G [00:02<00:13, 315MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  19%|█▏    | 940M/4.98G [00:03<00:12, 334MB/s]
# model-00010-of-00019.safetensors:  55%|██▋  | 2.69G/4.90G [00:04<00:03, 562MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  18%|█     | 873M/4.98G [00:03<00:11, 371MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  13%|▊     | 671M/4.98G [00:03<00:18, 239MB/s]
#
#
# model-00009-of-00019.safetensors:  61%|███  | 3.02G/4.98G [00:05<00:03, 618MB/s]
# model-00010-of-00019.safetensors:  58%|██▉  | 2.82G/4.90G [00:04<00:03, 586MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  19%|█▏    | 940M/4.98G [00:03<00:11, 357MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  20%|█    | 1.01G/4.98G [00:03<00:12, 308MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  20%|█    | 1.01G/4.98G [00:03<00:08, 494MB/s]
#
#
# model-00009-of-00019.safetensors:  63%|███▏ | 3.15G/4.98G [00:05<00:03, 595MB/s]
# model-00010-of-00019.safetensors:  60%|███  | 2.95G/4.90G [00:04<00:03, 641MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  20%|█    | 1.01G/4.98G [00:03<00:10, 372MB/s]
#
#
# model-00009-of-00019.safetensors:  66%|███▎ | 3.29G/4.98G [00:05<00:02, 618MB/s]
#
# model-00015-of-00019.safetensors:  11%|▋     | 536M/4.98G [00:03<00:26, 166MB/s]
# model-00010-of-00019.safetensors:  64%|███▏ | 3.15G/4.90G [00:04<00:02, 711MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  23%|█▏   | 1.14G/4.98G [00:04<00:10, 352MB/s]
#
#
#
# model-00016-of-00019.safetensors:  13%|▊     | 671M/4.98G [00:03<00:20, 211MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  22%|█    | 1.07G/4.98G [00:04<00:11, 352MB/s]
# model-00010-of-00019.safetensors:  67%|███▎ | 3.29G/4.90G [00:05<00:02, 785MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  24%|█▏   | 1.21G/4.98G [00:04<00:10, 372MB/s]
#
# model-00015-of-00019.safetensors:  19%|█▏    | 940M/4.98G [00:03<00:08, 486MB/s]
#
#
#
# model-00016-of-00019.safetensors:  20%|█    | 1.01G/4.98G [00:03<00:09, 438MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  23%|█▏   | 1.14G/4.98G [00:04<00:12, 320MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  22%|█    | 1.07G/4.90G [00:04<00:14, 262MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  27%|█▎   | 1.34G/4.98G [00:04<00:06, 566MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  26%|█▎   | 1.28G/4.98G [00:04<00:11, 318MB/s]
# model-00010-of-00019.safetensors:  70%|███▍ | 3.42G/4.90G [00:05<00:02, 559MB/s]
#
# model-00015-of-00019.safetensors:  22%|█    | 1.07G/4.98G [00:04<00:09, 423MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  23%|█▏   | 1.14G/4.98G [00:04<00:12, 316MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  30%|█▍   | 1.48G/4.98G [00:04<00:05, 608MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  27%|█▎   | 1.34G/4.98G [00:04<00:11, 328MB/s]
#
#
#
# model-00016-of-00019.safetensors:  22%|█    | 1.08G/4.98G [00:04<00:11, 343MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  31%|█▌   | 1.55G/4.98G [00:04<00:06, 523MB/s]
#
#
# model-00009-of-00019.safetensors:  69%|███▍ | 3.42G/4.98G [00:06<00:04, 353MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  26%|█▎   | 1.28G/4.98G [00:04<00:10, 357MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  26%|█▎   | 1.27G/4.90G [00:04<00:11, 305MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  32%|█▌   | 1.61G/4.98G [00:05<00:05, 577MB/s]
# model-00010-of-00019.safetensors:  73%|███▋ | 3.56G/4.90G [00:05<00:02, 504MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  27%|█▎   | 1.34G/4.98G [00:04<00:09, 380MB/s]
#
#
# model-00009-of-00019.safetensors:  75%|███▊ | 3.76G/4.98G [00:06<00:02, 598MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  27%|█▎   | 1.34G/4.90G [00:05<00:10, 324MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  35%|█▊   | 1.74G/4.98G [00:05<00:04, 653MB/s]
# model-00010-of-00019.safetensors:  75%|███▊ | 3.69G/4.90G [00:05<00:02, 578MB/s]
#
#
#
# model-00016-of-00019.safetensors:  23%|█▏   | 1.14G/4.98G [00:04<00:13, 280MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  34%|█▋   | 1.68G/4.98G [00:05<00:07, 434MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  38%|█▉   | 1.88G/4.98G [00:05<00:04, 663MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  29%|█▍   | 1.41G/4.90G [00:05<00:10, 318MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  31%|█▌   | 1.54G/4.98G [00:05<00:07, 448MB/s]
#
#
# model-00009-of-00019.safetensors:  78%|███▉ | 3.89G/4.98G [00:07<00:02, 541MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  35%|█▊   | 1.75G/4.98G [00:05<00:07, 460MB/s]
#
# model-00015-of-00019.safetensors:  24%|█▏   | 1.21G/4.98G [00:05<00:12, 295MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  33%|█▋   | 1.61G/4.90G [00:05<00:07, 437MB/s]
#
#
#
# model-00016-of-00019.safetensors:  24%|█▏   | 1.21G/4.98G [00:04<00:14, 268MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  38%|█▉   | 1.88G/4.98G [00:05<00:05, 540MB/s]
#
# model-00015-of-00019.safetensors:  26%|█▎   | 1.27G/4.98G [00:05<00:12, 308MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  36%|█▊   | 1.74G/4.90G [00:05<00:06, 505MB/s]
#
#
#
# model-00016-of-00019.safetensors:  26%|█▎   | 1.28G/4.98G [00:05<00:14, 265MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  39%|█▉   | 1.95G/4.98G [00:05<00:06, 443MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  40%|██   | 2.01G/4.98G [00:05<00:06, 432MB/s]
#
# model-00015-of-00019.safetensors:  28%|█▍   | 1.41G/4.98G [00:05<00:09, 369MB/s]
# model-00010-of-00019.safetensors:  78%|███▉ | 3.83G/4.90G [00:06<00:02, 359MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  37%|█▊   | 1.81G/4.90G [00:05<00:06, 471MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  34%|█▋   | 1.68G/4.98G [00:05<00:09, 357MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  43%|██▏  | 2.15G/4.98G [00:06<00:05, 541MB/s]
#
# model-00015-of-00019.safetensors:  30%|█▍   | 1.48G/4.98G [00:05<00:08, 396MB/s]
# model-00010-of-00019.safetensors:  79%|███▉ | 3.89G/4.90G [00:06<00:02, 375MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  40%|█▉   | 1.95G/4.90G [00:05<00:05, 574MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  36%|█▊   | 1.81G/4.98G [00:05<00:07, 443MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  42%|██   | 2.08G/4.98G [00:06<00:06, 476MB/s]
#
# model-00015-of-00019.safetensors:  32%|█▌   | 1.61G/4.98G [00:05<00:06, 507MB/s]
#
#
# model-00009-of-00019.safetensors:  81%|████ | 4.03G/4.98G [00:07<00:02, 362MB/s]
#
# model-00015-of-00019.safetensors:  35%|█▊   | 1.74G/4.98G [00:05<00:05, 626MB/s]
# model-00010-of-00019.safetensors:  81%|████ | 3.96G/4.90G [00:07<00:02, 361MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  42%|██   | 2.08G/4.90G [00:06<00:04, 589MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  40%|██   | 2.01G/4.98G [00:06<00:05, 576MB/s]
#
#
#
# model-00016-of-00019.safetensors:  28%|█▍   | 1.41G/4.98G [00:05<00:12, 285MB/s]
#
#
# model-00009-of-00019.safetensors:  83%|████▏| 4.11G/4.98G [00:08<00:02, 400MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  44%|██▏  | 2.22G/4.98G [00:06<00:05, 535MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  46%|██▎  | 2.28G/4.98G [00:06<00:05, 493MB/s]
# model-00010-of-00019.safetensors:  84%|████▏| 4.09G/4.90G [00:07<00:01, 464MB/s]
#
#
# model-00009-of-00019.safetensors:  85%|████▎| 4.25G/4.98G [00:08<00:01, 490MB/s]
#
#
#
# model-00016-of-00019.safetensors:  31%|█▌   | 1.55G/4.98G [00:05<00:08, 385MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  46%|██▎  | 2.28G/4.98G [00:06<00:04, 544MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  43%|██▏  | 2.15G/4.98G [00:06<00:05, 544MB/s]
# model-00010-of-00019.safetensors:  85%|████▏| 4.16G/4.90G [00:07<00:01, 440MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  48%|██▍  | 2.41G/4.98G [00:06<00:05, 476MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  44%|██▏  | 2.15G/4.90G [00:06<00:07, 385MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  46%|██▎  | 2.28G/4.98G [00:06<00:04, 592MB/s]
# model-00010-of-00019.safetensors:  88%|████▍| 4.29G/4.90G [00:07<00:01, 472MB/s]
#
#
#
# model-00016-of-00019.safetensors:  34%|█▋   | 1.68G/4.98G [00:06<00:09, 347MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  47%|██▎  | 2.35G/4.98G [00:06<00:07, 336MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  51%|██▌  | 2.55G/4.98G [00:06<00:05, 463MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  45%|██▎  | 2.22G/4.90G [00:06<00:07, 355MB/s]
#
#
#
# model-00016-of-00019.safetensors:  35%|█▊   | 1.75G/4.98G [00:06<00:09, 348MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  48%|██▍  | 2.42G/4.98G [00:06<00:07, 347MB/s]
#
# model-00015-of-00019.safetensors:  38%|█▉   | 1.88G/4.98G [00:06<00:09, 324MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  48%|██▍  | 2.35G/4.90G [00:06<00:05, 462MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  48%|██▍  | 2.42G/4.98G [00:07<00:05, 494MB/s]
# model-00010-of-00019.safetensors:  89%|████▍| 4.36G/4.90G [00:07<00:01, 363MB/s]
#
#
#
# model-00016-of-00019.safetensors:  38%|█▉   | 1.88G/4.98G [00:06<00:06, 463MB/s]
#
#
# model-00009-of-00019.safetensors:  88%|████▍| 4.38G/4.98G [00:08<00:01, 320MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  50%|██▍  | 2.48G/4.98G [00:07<00:04, 514MB/s]
#
#
#
# model-00016-of-00019.safetensors:  40%|██   | 2.01G/4.98G [00:06<00:05, 552MB/s]
#
#
# model-00009-of-00019.safetensors:  92%|████▌| 4.58G/4.98G [00:09<00:01, 390MB/s]
# model-00010-of-00019.safetensors:  92%|████▌| 4.50G/4.90G [00:08<00:01, 357MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  53%|██▋  | 2.62G/4.98G [00:07<00:08, 292MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  49%|██▍  | 2.42G/4.90G [00:07<00:08, 276MB/s]
#
#
# model-00009-of-00019.safetensors:  95%|████▋| 4.72G/4.98G [00:09<00:00, 440MB/s]
# model-00010-of-00019.safetensors:  96%|████▊| 4.70G/4.90G [00:08<00:00, 522MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  51%|██▌  | 2.55G/4.98G [00:07<00:09, 266MB/s]
#
# model-00015-of-00019.safetensors:  43%|██▏  | 2.15G/4.98G [00:07<00:08, 353MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  56%|██▊  | 2.75G/4.90G [00:07<00:03, 579MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  51%|██▌  | 2.55G/4.98G [00:07<00:08, 290MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  59%|██▉  | 2.95G/4.98G [00:07<00:03, 616MB/s]
#
# model-00015-of-00019.safetensors:  44%|██▏  | 2.22G/4.98G [00:07<00:07, 368MB/s]
#
#
# model-00009-of-00019.safetensors:  97%|████▊| 4.85G/4.98G [00:09<00:00, 477MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  58%|██▉  | 2.89G/4.98G [00:07<00:05, 419MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  55%|██▊  | 2.75G/4.98G [00:07<00:04, 454MB/s]
#
#
# model-00009-of-00019.safetensors:  99%|████▉| 4.92G/4.98G [00:09<00:00, 485MB/s]
#
# model-00015-of-00019.safetensors:  50%|██▍  | 2.48G/4.98G [00:07<00:04, 577MB/s]
#
#
#
# model-00016-of-00019.safetensors:  43%|██▏  | 2.15G/4.98G [00:07<00:08, 332MB/s]
# model-00010-of-00019.safetensors:  97%|████▊| 4.77G/4.90G [00:08<00:00, 397MB/s]
#
#
#
# model-00016-of-00019.safetensors:  49%|██▍  | 2.42G/4.98G [00:07<00:04, 537MB/s]
#
#
# model-00009-of-00019.safetensors: 100%|█████| 4.98G/4.98G [00:10<00:00, 438MB/s]
#
#
#
#
#
# model-00009-of-00019.safetensors: 100%|█████| 4.98G/4.98G [00:10<00:00, 496MB/s]
# Fetching 19 files:  47%|███████████▊             | 9/19 [00:21<00:18,  1.84s/it]
#
#
#
# model-00016-of-00019.safetensors:  51%|██▌  | 2.55G/4.98G [00:07<00:04, 607MB/s]
#
#
# model-00017-of-00019.safetensors:   0%|             | 0.00/4.90G [00:00<?, ?B/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  61%|███  | 3.02G/4.98G [00:08<00:05, 356MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  59%|██▉  | 2.89G/4.90G [00:08<00:05, 376MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  66%|███▎ | 3.29G/4.98G [00:08<00:02, 599MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  58%|██▉  | 2.89G/4.98G [00:08<00:06, 318MB/s]
#
#
#
# model-00016-of-00019.safetensors:  54%|██▋  | 2.69G/4.98G [00:08<00:04, 512MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  71%|███▌ | 3.55G/4.98G [00:08<00:01, 834MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  62%|███  | 3.02G/4.90G [00:08<00:04, 432MB/s]
#
# model-00015-of-00019.safetensors:  53%|██▋  | 2.62G/4.98G [00:08<00:06, 379MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  62%|███  | 3.09G/4.98G [00:08<00:05, 339MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  77%|███ | 3.82G/4.98G [00:08<00:01, 1.04GB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  65%|███▏ | 3.22G/4.98G [00:08<00:04, 413MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  66%|███▎ | 3.22G/4.90G [00:08<00:03, 531MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  82%|███▎| 4.09G/4.98G [00:09<00:00, 1.32GB/s]
#
# model-00015-of-00019.safetensors:  58%|██▉  | 2.89G/4.98G [00:08<00:04, 514MB/s]
# model-00010-of-00019.safetensors: 100%|█████| 4.90G/4.90G [00:09<00:00, 245MB/s]
#
#
#
# model-00010-of-00019.safetensors: 100%|█████| 4.90G/4.90G [00:09<00:00, 496MB/s]
# Fetching 19 files:  53%|████████████▋           | 10/19 [00:22<00:15,  1.68s/it]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  61%|███  | 3.02G/4.98G [00:08<00:05, 332MB/s]
#
#
#
# model-00016-of-00019.safetensors:  58%|██▉  | 2.89G/4.98G [00:08<00:04, 508MB/s]
#
# model-00015-of-00019.safetensors:  61%|███  | 3.02G/4.98G [00:08<00:03, 586MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  67%|███▎ | 3.35G/4.98G [00:09<00:03, 471MB/s]
# model-00018-of-00019.safetensors:   0%|             | 0.00/4.98G [00:00<?, ?B/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  62%|███  | 3.09G/4.98G [00:09<00:05, 318MB/s]
#
# model-00015-of-00019.safetensors:  63%|███▏ | 3.15G/4.98G [00:08<00:03, 524MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  70%|███▍ | 3.42G/4.90G [00:09<00:03, 474MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  70%|███▍ | 3.49G/4.98G [00:09<00:03, 444MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  86%|████▎| 4.29G/4.98G [00:09<00:00, 799MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  63%|███▏ | 3.15G/4.98G [00:09<00:06, 284MB/s]
#
#
#
# model-00016-of-00019.safetensors:  59%|██▉  | 2.95G/4.98G [00:08<00:06, 316MB/s]
#
# model-00015-of-00019.safetensors:  65%|███▎ | 3.24G/4.98G [00:09<00:03, 490MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  73%|███▋ | 3.56G/4.90G [00:09<00:02, 489MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  73%|███▋ | 3.62G/4.98G [00:09<00:02, 471MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  89%|████▍| 4.43G/4.98G [00:09<00:00, 726MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  92%|████▌| 4.56G/4.98G [00:09<00:00, 804MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  70%|███▍ | 3.49G/4.98G [00:09<00:02, 542MB/s]
#
# model-00015-of-00019.safetensors:  66%|███▎ | 3.31G/4.98G [00:09<00:03, 461MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  77%|███▊ | 3.76G/4.90G [00:09<00:01, 612MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  75%|███▊ | 3.76G/4.98G [00:09<00:02, 522MB/s]
#
#
#
# model-00016-of-00019.safetensors:  62%|███  | 3.09G/4.98G [00:09<00:05, 370MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  78%|███▉ | 3.89G/4.98G [00:09<00:01, 633MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  73%|███▋ | 3.62G/4.98G [00:10<00:02, 549MB/s]
#
# model-00015-of-00019.safetensors:  68%|███▍ | 3.37G/4.98G [00:09<00:03, 411MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  80%|███▉ | 3.90G/4.90G [00:10<00:01, 577MB/s]
#
#
#
# model-00016-of-00019.safetensors:  65%|███▏ | 3.22G/4.98G [00:09<00:04, 382MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  96%|████▊| 4.78G/4.98G [00:10<00:00, 619MB/s]
#
# model-00015-of-00019.safetensors:  69%|███▍ | 3.44G/4.98G [00:09<00:04, 370MB/s]
#
#
#
# model-00016-of-00019.safetensors:  69%|███▍ | 3.42G/4.98G [00:09<00:02, 551MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  75%|███▊ | 3.76G/4.98G [00:10<00:02, 511MB/s]
#
#
# model-00017-of-00019.safetensors:   1%|    | 67.1M/4.90G [00:02<02:27, 32.6MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  82%|████ | 4.03G/4.90G [00:10<00:01, 532MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  81%|████ | 4.02G/4.98G [00:10<00:02, 455MB/s]
#
#
#
# model-00016-of-00019.safetensors:  71%|███▌ | 3.56G/4.98G [00:09<00:02, 612MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  78%|███▉ | 3.89G/4.98G [00:10<00:01, 574MB/s]
#
#
# model-00017-of-00019.safetensors:   4%|▏     | 201M/4.90G [00:02<00:41, 114MB/s]
#
# model-00015-of-00019.safetensors:  72%|███▌ | 3.57G/4.98G [00:10<00:03, 433MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  83%|████▏| 4.16G/4.98G [00:10<00:01, 563MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  84%|████▏| 4.10G/4.90G [00:10<00:01, 474MB/s]
#
#
#
#
#
# model-00011-of-00019.safetensors:  99%|████▉| 4.92G/4.98G [00:10<00:00, 506MB/s]
#
#
#
# model-00016-of-00019.safetensors:  74%|███▋ | 3.69G/4.98G [00:10<00:02, 600MB/s]
#
#
# model-00017-of-00019.safetensors:   5%|▎     | 268M/4.90G [00:02<00:31, 145MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  81%|████ | 4.04G/4.98G [00:10<00:01, 606MB/s]
#
# model-00011-of-00019.safetensors: 100%|█████| 4.98G/4.98G [00:10<00:00, 458MB/s]
# Fetching 19 files:  58%|█████████████▉          | 11/19 [00:24<00:13,  1.70s/it]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  85%|████▏| 4.16G/4.90G [00:10<00:01, 481MB/s]
#
#
#
#
#
# model-00019-of-00019.safetensors:   0%|             | 0.00/4.22G [00:00<?, ?B/s]
#
#
#
# model-00016-of-00019.safetensors:  77%|███▊ | 3.82G/4.98G [00:10<00:01, 656MB/s]
#
# model-00015-of-00019.safetensors:  76%|███▊ | 3.78G/4.98G [00:10<00:02, 462MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  86%|████▎| 4.23G/4.90G [00:10<00:01, 448MB/s]
# model-00018-of-00019.safetensors:   1%|    | 67.1M/4.98G [00:01<02:08, 38.3MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  85%|████▎| 4.25G/4.98G [00:10<00:01, 405MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  84%|████▏| 4.18G/4.98G [00:11<00:01, 565MB/s]
#
# model-00015-of-00019.safetensors:  77%|███▊ | 3.84G/4.98G [00:10<00:02, 484MB/s]
#
#
# model-00017-of-00019.safetensors:   7%|▍     | 336M/4.90G [00:02<00:29, 157MB/s]
#
# model-00015-of-00019.safetensors:  78%|███▉ | 3.91G/4.98G [00:10<00:02, 470MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  90%|████▌| 4.43G/4.90G [00:11<00:00, 574MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  91%|████▌| 4.51G/4.98G [00:11<00:00, 563MB/s]
#
#
#
# model-00016-of-00019.safetensors:  79%|███▉ | 3.91G/4.98G [00:10<00:02, 471MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  85%|████▎| 4.25G/4.98G [00:11<00:01, 458MB/s]
# model-00018-of-00019.safetensors:   4%|▏     | 201M/4.98G [00:02<00:41, 116MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  92%|████▌| 4.50G/4.90G [00:11<00:00, 518MB/s]
#
#
#
# model-00016-of-00019.safetensors:  81%|████ | 4.04G/4.98G [00:10<00:01, 567MB/s]
#
# model-00015-of-00019.safetensors:  80%|███▉ | 3.98G/4.98G [00:10<00:02, 423MB/s]
#
#
# model-00017-of-00019.safetensors:  11%|▋     | 537M/4.90G [00:03<00:15, 285MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  93%|████▋| 4.65G/4.98G [00:11<00:00, 607MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  95%|████▋| 4.63G/4.90G [00:11<00:00, 657MB/s]
# model-00018-of-00019.safetensors:   7%|▍     | 335M/4.98G [00:02<00:22, 207MB/s]
#
# model-00015-of-00019.safetensors:  84%|████▏| 4.18G/4.98G [00:11<00:01, 526MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  89%|████▍| 4.45G/4.98G [00:11<00:01, 477MB/s]
# model-00018-of-00019.safetensors:  11%|▋     | 536M/4.98G [00:02<00:13, 318MB/s]
#
#
#
# model-00016-of-00019.safetensors:  85%|████▎| 4.25G/4.98G [00:11<00:01, 524MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  91%|████▌| 4.51G/4.98G [00:11<00:00, 482MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  92%|████▌| 4.58G/4.98G [00:11<00:00, 485MB/s]
#
# model-00015-of-00019.safetensors:  87%|████▎| 4.31G/4.98G [00:11<00:01, 507MB/s]
#
#
#
#
#
#
# model-00014-of-00019.safetensors:  97%|████▊| 4.76G/4.90G [00:11<00:00, 448MB/s]
#
#
# model-00017-of-00019.safetensors:  14%|▊     | 671M/4.90G [00:03<00:16, 262MB/s]
#
#
#
#
# model-00014-of-00019.safetensors: 100%|█████| 4.90G/4.90G [00:12<00:00, 406MB/s]
#
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  93%|████▋| 4.65G/4.98G [00:12<00:00, 469MB/s]
#
#
# model-00017-of-00019.safetensors:  21%|█    | 1.01G/4.90G [00:03<00:07, 520MB/s]
#
#
#
# model-00016-of-00019.safetensors:  87%|████▎| 4.31G/4.98G [00:11<00:01, 419MB/s]
#
# model-00015-of-00019.safetensors:  89%|████▍| 4.45G/4.98G [00:11<00:00, 574MB/s]
#
#
#
#
# model-00012-of-00019.safetensors:  99%|████▉| 4.92G/4.98G [00:12<00:00, 467MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  95%|████▋| 4.71G/4.98G [00:12<00:00, 471MB/s]
#
#
#
# model-00016-of-00019.safetensors:  88%|████▍| 4.38G/4.98G [00:11<00:01, 405MB/s]
#
# model-00015-of-00019.safetensors:  91%|████▌| 4.51G/4.98G [00:11<00:00, 499MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  97%|████▊| 4.85G/4.98G [00:12<00:00, 568MB/s]
# model-00018-of-00019.safetensors:  12%|▋     | 604M/4.98G [00:03<00:19, 227MB/s]
#
#
#
# model-00016-of-00019.safetensors:  89%|████▍| 4.45G/4.98G [00:11<00:01, 437MB/s]
#
# model-00015-of-00019.safetensors:  95%|████▋| 4.71G/4.98G [00:12<00:00, 730MB/s]
#
#
#
#
# model-00012-of-00019.safetensors: 100%|█████| 4.98G/4.98G [00:12<00:00, 398MB/s]
# Fetching 19 files:  63%|███████████████▏        | 12/19 [00:25<00:11,  1.71s/it]
#
#
#
# model-00016-of-00019.safetensors:  91%|████▌| 4.51G/4.98G [00:11<00:01, 430MB/s]
#
# model-00015-of-00019.safetensors:  97%|████▊| 4.85G/4.98G [00:12<00:00, 770MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors:  99%|████▉| 4.92G/4.98G [00:12<00:00, 464MB/s]
#
#
#
# model-00016-of-00019.safetensors:  95%|████▋| 4.71G/4.98G [00:12<00:00, 694MB/s]
# model-00018-of-00019.safetensors:  20%|█    | 1.01G/4.98G [00:03<00:08, 478MB/s]
#
#
#
#
#
#
#
# model-00013-of-00019.safetensors: 100%|█████| 4.98G/4.98G [00:12<00:00, 390MB/s]
# Fetching 19 files:  68%|████████████████▍       | 13/19 [00:26<00:08,  1.39s/it]
#
#
#
# model-00016-of-00019.safetensors:  97%|████▊| 4.85G/4.98G [00:12<00:00, 816MB/s]
#
#
#
#
#
# model-00019-of-00019.safetensors:   0%|    | 612k/4.22G [00:02<3:57:52, 296kB/s]
#
# model-00015-of-00019.safetensors: 100%|█████| 4.98G/4.98G [00:12<00:00, 398MB/s]
# Fetching 19 files:  79%|██████████████████▉     | 15/19 [00:26<00:03,  1.14it/s]
#
#
#
# model-00016-of-00019.safetensors: 100%|█████| 4.98G/4.98G [00:12<00:00, 731MB/s]
#
#
#
#
#
# model-00016-of-00019.safetensors: 100%|█████| 4.98G/4.98G [00:12<00:00, 401MB/s]
# Fetching 19 files:  84%|████████████████████▏   | 16/19 [00:26<00:02,  1.40it/s]
# model-00018-of-00019.safetensors:  23%|█▏   | 1.14G/4.98G [00:04<00:10, 371MB/s]
#
#
# model-00017-of-00019.safetensors:  23%|█▏   | 1.14G/4.90G [00:05<00:15, 248MB/s]
#
#
# model-00017-of-00019.safetensors:  49%|██▍  | 2.42G/4.90G [00:05<00:02, 986MB/s]
#
#
#
#
#
# model-00019-of-00019.safetensors:  27%|█▎   | 1.14G/4.22G [00:03<00:07, 416MB/s]
#
#
# model-00017-of-00019.safetensors:  58%|██▉  | 2.82G/4.90G [00:05<00:02, 885MB/s]
# model-00018-of-00019.safetensors:  26%|█▎   | 1.28G/4.98G [00:05<00:13, 267MB/s]
#
#
#
#
#
# model-00019-of-00019.safetensors:  40%|█▉   | 1.68G/4.22G [00:03<00:03, 693MB/s]
# model-00018-of-00019.safetensors:  51%|██  | 2.55G/4.98G [00:05<00:02, 1.07GB/s]
#
#
#
#
#
# model-00019-of-00019.safetensors:  46%|██▎  | 1.95G/4.22G [00:03<00:02, 837MB/s]
#
#
# model-00017-of-00019.safetensors:  64%|███▏ | 3.16G/4.90G [00:06<00:01, 928MB/s]
#
#
# model-00017-of-00019.safetensors:  70%|██▊ | 3.42G/4.90G [00:06<00:01, 1.06GB/s]
#
#
# model-00017-of-00019.safetensors:  77%|███ | 3.76G/4.90G [00:06<00:00, 1.27GB/s]
#
#
# model-00017-of-00019.safetensors:  82%|███▎| 4.03G/4.90G [00:06<00:00, 1.41GB/s]
#
#
#
#
#
# model-00019-of-00019.safetensors:  52%|██▌  | 2.21G/4.22G [00:04<00:02, 712MB/s]
#
#
# model-00017-of-00019.safetensors:  92%|███▋| 4.50G/4.90G [00:06<00:00, 1.90GB/s]
#
#
#
#
#
# model-00019-of-00019.safetensors:  57%|██▊  | 2.42G/4.22G [00:04<00:02, 780MB/s]
#
#
# model-00017-of-00019.safetensors:  99%|███▉| 4.83G/4.90G [00:06<00:00, 1.96GB/s]
# model-00018-of-00019.safetensors:  60%|██▉  | 2.97G/4.98G [00:06<00:02, 798MB/s]
#
#
#
#
#
# model-00017-of-00019.safetensors: 100%|█████| 4.90G/4.90G [00:07<00:00, 695MB/s]
# Fetching 19 files:  89%|█████████████████████▍  | 17/19 [00:28<00:02,  1.08s/it]
#
#
#
#
#
# model-00019-of-00019.safetensors:  70%|██▊ | 2.95G/4.22G [00:04<00:01, 1.08GB/s]
#
#
#
#
#
# model-00019-of-00019.safetensors:  75%|██▉ | 3.15G/4.22G [00:04<00:00, 1.17GB/s]
# model-00018-of-00019.safetensors:  66%|███▎ | 3.31G/4.98G [00:06<00:01, 869MB/s]
#
#
#
#
#
# model-00019-of-00019.safetensors:  81%|███▏| 3.42G/4.22G [00:04<00:00, 1.34GB/s]
# model-00018-of-00019.safetensors:  72%|███▌ | 3.57G/4.98G [00:06<00:01, 942MB/s]
#
#
#
#
#
# model-00019-of-00019.safetensors:  86%|███▍| 3.62G/4.22G [00:05<00:00, 1.37GB/s]
# model-00018-of-00019.safetensors:  80%|███▏| 3.98G/4.98G [00:06<00:00, 1.23GB/s]
#
#
#
#
#
# model-00019-of-00019.safetensors:  95%|███▊| 4.02G/4.22G [00:05<00:00, 1.85GB/s]
# model-00019-of-00019.safetensors: 100%|█████| 4.22G/4.22G [00:05<00:00, 807MB/s]
#
# model-00018-of-00019.safetensors: 100%|█████| 4.98G/4.98G [00:07<00:00, 694MB/s]
# Fetching 19 files: 100%|████████████████████████| 19/19 [00:29<00:00,  1.56s/it]
# Loading checkpoint shards: 100%|████████████████| 19/19 [00:18<00:00,  1.01it/s]
# generation_config.json: 100%|██████████████████| 116/116 [00:00<00:00, 1.49MB/s]
# vocab size:  32000
# [2025-12-31 14:24:13 root](main.py 324): INFO === start quantization ===
# get_wikitext2
# README.md: 10.5kB [00:00, 40.6MB/s]
# wikitext-2-raw-v1/test-00000-of-00001.pa(…): 100%|█| 733k/733k [00:00<00:00, 5.0
# wikitext-2-raw-v1/train-00000-of-00001.p(…): 100%|█| 6.36M/6.36M [00:00<00:00, 2
# wikitext-2-raw-v1/validation-00000-of-00(…): 100%|█| 657k/657k [00:00<00:00, 5.2
# Generating test split: 100%|█████| 4358/4358 [00:00<00:00, 571533.26 examples/s]
# Generating train split: 100%|█| 36718/36718 [00:00<00:00, 1171641.78 examples/s]
# Generating validation split: 100%|█| 3760/3760 [00:00<00:00, 1080028.97 examples
# [2025-12-31 14:24:35 root](omniquant.py 50): INFO Starting ...
# [2025-12-31 14:24:38 root](omniquant.py 193): INFO === Start quantize layer 0 ===
# /workspace/OmniQuant-main/quantize/omniquant.py:211: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Traceback (most recent call last):
#   File "/workspace/OmniQuant-main/main.py", line 375, in <module>
#     main()
#   File "/workspace/OmniQuant-main/main.py", line 345, in main
#     omniquant(
#   File "/workspace/OmniQuant-main/quantize/omniquant.py", line 213, in omniquant
#     fp_inps[j] = qlayer(fp_inps[j].unsqueeze(0), attention_mask=attention_mask,position_ids=position_ids)[0]
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/modeling_layers.py", line 94, in __call__
#     return super().__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1786, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/transformers/utils/deprecation.py", line 172, in wrapped_func
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
# TypeError: MixtralDecoderLayer.forward() missing 1 required positional argument: 'position_embeddings'

# %%
# !ls -lh ./pre_quantized_models/Mixtral-8x7B-v0.1-OmniQuantv1-w4a16g128/*.safetensors
# !head -n 3 ./pre_quantized_models/Mixtral-8x7B-v0.1-OmniQuantv1-w4a16g128/*.safetensors | cat
# Out:
# -rw-rw-rw- 1 root root 135 Dec 31 14:06 ./pre_quantized_models/Mixtral-8x7B-v0.1-OmniQuantv1-w4a16g128/model-00001-of-00005.safetensors
# -rw-rw-rw- 1 root root 135 Dec 31 14:06 ./pre_quantized_models/Mixtral-8x7B-v0.1-OmniQuantv1-w4a16g128/model-00002-of-00005.safetensors
# -rw-rw-rw- 1 root root 135 Dec 31 14:06 ./pre_quantized_models/Mixtral-8x7B-v0.1-OmniQuantv1-w4a16g128/model-00003-of-00005.safetensors
# -rw-rw-rw- 1 root root 135 Dec 31 14:06 ./pre_quantized_models/Mixtral-8x7B-v0.1-OmniQuantv1-w4a16g128/model-00004-of-00005.safetensors
# -rw-rw-rw- 1 root root 135 Dec 31 14:06 ./pre_quantized_models/Mixtral-8x7B-v0.1-OmniQuantv1-w4a16g128/model-00005-of-00005.safetensors
# ==> ./pre_quantized_models/Mixtral-8x7B-v0.1-OmniQuantv1-w4a16g128/model-00001-of-00005.safetensors <==
# version https://git-lfs.github.com/spec/v1
# oid sha256:080f2cfc95ec820c702ed124dbd8558ca6f80d0852a8357310691bb628681f9b
# size 4996342672
#
# ==> ./pre_quantized_models/Mixtral-8x7B-v0.1-OmniQuantv1-w4a16g128/model-00002-of-00005.safetensors <==
# version https://git-lfs.github.com/spec/v1
# oid sha256:786e792188adf7e839ffc6a530fd2194b7a0a102ff4935f5c2cae1f31f539ef8
# size 4987113160
#
# ==> ./pre_quantized_models/Mixtral-8x7B-v0.1-OmniQuantv1-w4a16g128/model-00003-of-00005.safetensors <==
# version https://git-lfs.github.com/spec/v1
# oid sha256:7bed461c4bdc81dbb9ca2cd01e9e95608df611bcc73cf3cac58fadbe50f4db87
# size 4978530024
#
# ==> ./pre_quantized_models/Mixtral-8x7B-v0.1-OmniQuantv1-w4a16g128/model-00004-of-00005.safetensors <==
# version https://git-lfs.github.com/spec/v1
# oid sha256:7f29ecc242f3347a1d16da2f11736fc87ae488364bc425ab09353739e58d90db
# size 4978489088
#
# ==> ./pre_quantized_models/Mixtral-8x7B-v0.1-OmniQuantv1-w4a16g128/model-00005-of-00005.safetensors <==
# version https://git-lfs.github.com/spec/v1
# oid sha256:91133375ec80b4ca6e9ea557e7eeaafe4e970f39fc16220d1f0ebcb15d5472f4
# size 4738754968

# %% [markdown]
# ## Download the prebuilt quantized model:

# %% [markdown]
# We have provide the prebuilt quantized model on Huggingface. In order to download the large weights, we'll have to use `git lfs`.

# %%
# !conda install git git-lfs
# !git lfs install
# Out:
# /bin/bash: line 1: conda: command not found
# git: 'lfs' is not a git command. See 'git --help'.
#
# The most similar command is
# 	log

# %%
# !mkdir -p pre_quantized_models/

# download mixtral-8x7b-v0.1 with w4a16g128 quantization
# !git clone https://huggingface.co/ChenMnZ/Mixtral-8x7B-v0.1-OmniQuantv1-w4a16g128 ./pre_quantized_models/Mixtral-8x7B-v0.1-OmniQuantv1-w4a16g128

# download mixtral-8x7b-v0.1-Instruct with w4a16g128 quantization
# !git clone https://huggingface.co/ChenMnZ/Mixtral-8x7B-Instruct-v0.1-OmniQuantv1-w4a16g128 ./pre_quantized_models/Mixtral-8x7B-Instruct-v0.1-OmniQuantv1-w4a16g128
# Out:
# fatal: destination path './pre_quantized_models/Mixtral-8x7B-v0.1-OmniQuantv1-w4a16g128' already exists and is not an empty directory.

# %% [markdown]
# ## Let's Infer!

# %% [markdown]
# Constraint in one GPU.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %% [markdown]
# Load model.

# %%
from accelerate import init_empty_weights, infer_auto_device_map, load_checkpoint_in_model
from transformers import AutoModelForCausalLM, AutoTokenizer, AutoConfig
import torch
import auto_gptq.nn_modules.qlinear.qlinear_cuda as qlinear_cuda
import auto_gptq.nn_modules.qlinear.qlinear_triton as qlinear_triton
from tqdm import tqdm
import gc   
import time

def get_named_linears(module):
    return {name: m for name, m in module.named_modules() if isinstance(m, torch.nn.Linear) and not 'gate' in name}

def set_op_by_name(layer, name, new_module):
    levels = name.split('.')
    if len(levels) > 1:
        mod_ = layer
        for l_idx in range(len(levels)-1):
            if levels[l_idx].isdigit():
                mod_ = mod_[int(levels[l_idx])]
            else:
                mod_ = getattr(mod_, levels[l_idx])
        setattr(mod_, levels[-1], new_module)
    else:
        setattr(layer, name, new_module)

# manually adjust the model_path, corresponding weight bit width, group size.
model_path = './pre_quantized_models/Mixtral-8x7B-v0.1-OmniQuantv1-w4a16g128'
wbits = 4
group_size = 128



config = AutoConfig.from_pretrained(model_path, trust_remote_code=True)
enc = AutoTokenizer.from_pretrained(model_path, use_fast=False, trust_remote_code=True)
with init_empty_weights():
    model = AutoModelForCausalLM.from_config(config=config,torch_dtype=torch.float16, trust_remote_code=True)

layers = model.model.layers
for i in tqdm(range(len(layers))):
    layer = layers[i]
    named_linears = get_named_linears(layer)
    for name, module in named_linears.items():
        if wbits in [2,4]:
            q_linear = qlinear_triton.QuantLinear(wbits, group_size, module.in_features,module.out_features,not module.bias is None,kernel_switch_threshold=128)
        elif wbits == 3:
            q_linear = qlinear_cuda.QuantLinear(wbits, group_size, module.in_features,module.out_features,not module.bias is None,kernel_switch_threshold=128)
        else:
            raise NotImplementedError("Only 2,3,4 bits are supported.")
        q_linear.to(next(layer.parameters()).device)
        set_op_by_name(layer, name, q_linear)
torch.cuda.empty_cache()
gc.collect()
model.tie_weights()
device_map = infer_auto_device_map(model)
print("Loading pre-computed quantized weights...")
load_checkpoint_in_model(model,checkpoint=model_path,device_map=device_map,offload_state_dict=True)
print("Loading pre-computed quantized weights Successfully")
# Out:
# 100%|██████████| 32/32 [00:04<00:00,  6.84it/s]
# Loading pre-computed quantized weights...
# ---------------------------------------------------------------------------
# SafetensorError                           Traceback (most recent call last)
# Cell In[17], line 56
#      54 device_map = infer_auto_device_map(model)
#      55 print("Loading pre-computed quantized weights...")
# ---> 56 load_checkpoint_in_model(model,checkpoint=model_path,device_map=device_map,offload_state_dict=True)
#      57 print("Loading pre-computed quantized weights Successfully")
#
# File /usr/local/lib/python3.11/dist-packages/accelerate/utils/modeling.py:1960, in load_checkpoint_in_model(model, checkpoint, device_map, offload_folder, dtype, offload_state_dict, offload_buffers, keep_in_fp32_modules, offload_8bit_bnb, strict, full_state_dict, broadcast_from_rank0)
#    1958     unexpected_keys.update(set(loaded_checkpoint.keys()) - model_keys)
#    1959 else:
# -> 1960     loaded_checkpoint = load_state_dict(checkpoint_file, device_map=device_map)
#    1962     for param_name, param in loaded_checkpoint.items():
#    1963         # skip SCB parameter (for 8-bit serialization)
#    1964         if "SCB" in param_name:
#
# File /usr/local/lib/python3.11/dist-packages/accelerate/utils/modeling.py:1632, in load_state_dict(checkpoint_file, device_map)
#    1621 """
#    1622 Load a checkpoint from a given file. If the checkpoint is in the safetensors format and a device map is passed, the
#    1623 weights can be fast-loaded directly on the GPU.
#    (...)
#    1629         name, once a given module name is inside, every submodule of it will be sent to the same device.
#    1630 """
#    1631 if checkpoint_file.endswith(".safetensors"):
# -> 1632     with safe_open(checkpoint_file, framework="pt") as f:
#    1633         metadata = f.metadata()
#    1634         weight_names = f.keys()
#
# SafetensorError: Error while deserializing header: header too large

# %% [markdown]
# Start inference.

# %%
model.eval()
prompt = "Hello my name is"
input_ids = enc(prompt, return_tensors='pt').input_ids.cuda()
model = model.cuda()
start_time = time.time()
output = model.generate(inputs=input_ids, max_new_tokens=128)
end_time = time.time()
speed = len(output[0])/(end_time-start_time)
print(enc.decode(output[0], skip_special_tokens=True))
print(f"speed:{speed:.2f}token/s max memory: {torch.cuda.max_memory_allocated(model.device)/ 1024**2:.2f}M")
